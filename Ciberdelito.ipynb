# %% [markdown]
# <a href="https://colab.research.google.com/github/Matiasdrm07/Mineria_istea_1-/blob/main/Ciberdelito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyexcel-ods
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.0/717.0 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for odfpy: filename=odfpy-1.4.1-py2.py3-none-any.whl size=160672 sha256=8de15f6a516dedc484832cda773afae7fafb76286dc00d83a27cd892240123ee
#   Stored in directory: /root/.cache/pip/wheels/c8/2e/95/90d94fe33903786937f3b8c33dd88807f792359c6424b40469
# Successfully built odfpy
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-81a7c846-aaf9-4451-8006-0b62ef265f78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81a7c846-aaf9-4451-8006-0b62ef265f78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
nombre_archivo = 'D.B.xlsx'

# %%
df = pd.read_excel(nombre_archivo)

# %%
df.head()
# Out:
#    Edad: Sexo:       Nivel de estudio:  Ocupación:   Unnamed: 4 Unnamed: 5  \
# 0    NaN   NaN                      NaN   Empleado  Ama de casa    Docente
# 1   55.0     M               Secundario        NaN          NaN        NaN
# 2   32.0     F               Secundario   Empleado          NaN        NaN
# 3   42.0     F  Terciario/Universitario        NaN  Ama de casa        NaN
# 4   29.0     M               Secundario        NaN          NaN        NaN
#
#    Unnamed: 6     Unnamed: 7   Unnamed: 8   Unnamed: 9 Unnamed: 10  \
# 0  Estudiante  Independiente  Profesional  Comerciante    Jubilado
# 1         NaN            NaN          NaN  Comerciante         NaN
# 2         NaN            NaN          NaN          NaN         NaN
# 3         NaN            NaN          NaN          NaN         NaN
# 4         NaN            NaN          NaN  Comerciante         NaN
#
#           Unnamed: 11  \
# 0  Otro (especifique)
# 1                 NaN
# 2                 NaN
# ...

# %%
pd.set_option('display.max_columns', None)
